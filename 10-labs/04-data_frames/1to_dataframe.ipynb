# %%
import os
import sys
import pandas
import numpy
import json

# %% [markdown]
# Convert dictioary to dataframe

# %%
with open('season_team_stats.json', 'r') as f:
     teams_dict = json.load(f)

# %%
dm = pandas.DataFrame.from_dict(teams_dict)
dm
# Out:
#               ANA  ATL  BOS  BUF  CAR  CBJ  CGY  CHI  COL  DAL ...   OTT  PHI  \
# GamesPlayed    82   82   82   82   82   82   82   82   82   82 ...    82   82
# GoalsAllowed  233  262  189  228  234  250  230  220  287  226 ...   245  216
# GoalsFor      235  218  244  240  231  210  241  252  221  222 ...   190  256
# Losses         35   48   36   39   42   48   41   38   52   40 ...    50   35
# Wins           47   34   46   43   40   34   41   44   30   42 ...    32   47
#
#               PHX  PIT   SJ  STL   TB  TOR  VAN  WSH
# GamesPlayed    82   82   82   82   82   82   82   82
# GoalsAllowed  220  196  208  228  234  245  180  191
# GoalsFor      226  228  243  236  241  213  258  219
# Losses         39   33   34   44   36   45   27   34
# Wins           43   49   48   38   46   37   55   48
#
# [5 rows x 30 columns]

# %% [markdown]
# Reset dataframe index

# %%
dm = pandas.DataFrame.from_dict(teams_dict, orient='index')
dm.head()
# Out:
#      GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# ANA           82       235           233    47      35
# ATL           82       218           262    34      48
# BOS           82       244           189    46      36
# BUF           82       240           228    43      39
# CAR           82       231           234    40      42

# %% [markdown]
# Read csv to dataframe

# %%
dm = pandas.read_csv('NHL_season_team_goals.csv')
dm.head()
# Out:
#   Team  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# 0  ANA           82       235           233    47      35
# 1  ATL           82       218           262    34      48
# 2  BOS           82       244           189    46      36
# 3  BUF           82       240           228    43      39
# 4  CAR           82       231           234    40      42

# %% [markdown]
# # Dataframes
# * indecies: columns and rows
# * values: observations

# %%
dm.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
dm.columns
# Out:
# Index(['Team', 'GamesPlayed', 'GoalsFor', 'GoalsAllowed', 'Wins', 'Losses'], dtype='object')

# %%
# reset_index
dm = dm.reset_index()
dm.head()
# Out:
#    index Team  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# 0      0  ANA           82       235           233    47      35
# 1      1  ATL           82       218           262    34      48
# 2      2  BOS           82       244           189    46      36
# 3      3  BUF           82       240           228    43      39
# 4      4  CAR           82       231           234    40      42

# %%
# rename
dm = dm.rename(columns={'index': 'Team'})
dm.head()
# Out:
#   Team Team  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# 0    0  ANA           82       235           233    47      35
# 1    1  ATL           82       218           262    34      48
# 2    2  BOS           82       244           189    46      36
# 3    3  BUF           82       240           228    43      39
# 4    4  CAR           82       231           234    40      42

# %%
# Call a columns a series
#dm.GamesPlayed

# %%
# Call a columns a dataframe
dm[['GamesPlayed']]
# Out:
#     GamesPlayed
# 0            82
# 1            82
# 2            82
# 3            82
# 4            82
# 5            82
# 6            82
# 7            82
# 8            82
# 9            82
# 10           82
# 11           82
# 12           82
# 13           82
# 14           82
# 15           82
# 16           82
# 17           82
# 18           82
# 19           82
# 20           82
# 21           82
# 22           82
# 23           82
# 24           82
# 25           82
# 26           82
# 27           82
# 28           82
# 29           82

# %%
dm[['GamesPlayed', 'GoalsFor']].head()
# Out:
#    GamesPlayed  GoalsFor
# 0           82       235
# 1           82       218
# 2           82       244
# 3           82       240
# 4           82       231

# %%
# Create columns
dm['WP'] = dm.Wins/dm.GamesPlayed
dm['EWP'] = dm.GoalsFor**2 / (dm.GoalsFor**2 + dm.GoalsAllowed**2)
dm.head()
# Out:
#   index  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses       EWP        WP
# 0   ANA           82       235           233    47      35  0.504273  0.573171
# 1   ATL           82       218           262    34      48  0.409097  0.414634
# 2   BOS           82       244           189    46      36  0.625004  0.560976
# 3   BUF           82       240           228    43      39  0.525624  0.524390
# 4   CAR           82       231           234    40      42  0.493549  0.487805

# %%
# Slicing
dm[:5]
# Out:
#   index  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses       EWP        WP
# 0   ANA           82       235           233    47      35  0.504273  0.573171
# 1   ATL           82       218           262    34      48  0.409097  0.414634
# 2   BOS           82       244           189    46      36  0.625004  0.560976
# 3   BUF           82       240           228    43      39  0.525624  0.524390
# 4   CAR           82       231           234    40      42  0.493549  0.487805

# %%
dm[4:5]
# Out:
#      GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses       EWP        WP
# CAR           82       231           234    40      42  0.493549  0.487805

# %%
dm['Team'] == 'ANA'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: Team, dtype: bool

# %%
dm[dm.Team=='ANA'].head()
# Out:
#   Team  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# 0  ANA           82       235           233    47      35

# %%
dm[dm.Wins>50]
# Out:
#    Team  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# 28  VAN           82       258           180    55      27
