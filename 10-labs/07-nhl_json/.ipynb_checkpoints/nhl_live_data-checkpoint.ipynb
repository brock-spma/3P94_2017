# %% [markdown]
# # NHL live play by play
# * http://statsapi.web.nhl.com/api/v1/game/2016020001/feed/live

# %% [markdown]
# ## Create dataframe with season-game-play observations
# * include play type and player information

# %%
import json

with open('NHL2016020001.json', 'r') as f:
     gm_dict = json.load(f)

# %%
gm_dict
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2017. All Rights Reserved.',
#  'gameData': {'datetime': {'dateTime': '2016-10-12T23:00:00Z',
#    'endDateTime': '2016-10-13T01:56:40Z'},
#   'game': {'pk': 2016020001, 'season': '20162017', 'type': 'R'},
#   'players': {'ID8467493': {'active': False,
#     'birthCity': 'Flesherton',
#     'birthCountry': 'CAN',
#     'birthDate': '1979-06-18',
#     'birthStateProvince': 'ON',
#     'firstName': 'Chris',
#     'fullName': 'Chris Neil',
#     'height': '6\' 1"',
#     'id': 8467493,
#     'lastName': 'Neil',
#     'link': '/api/v1/people/8467493',
#     'nationality': 'CAN',
#     'primaryNumber': '25',
#     'primaryPosition': {'abbreviation': 'RW',
#      'code': 'R',
#      'name': 'Right Wing',
#      'type': 'Forward'},
#     'rookie': False,
#     'rosterStatus': 'Y',
#     'shootsCatches': 'R',
# ...
