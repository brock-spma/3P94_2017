# %% [markdown]
# # Practice: Web-scraping
# * Use Beatiful Soup to extract the NHL play by play data from ESPN
# * Store that data in a  dataframe with season-game-play observations
# * [ESPN NHL play by play](http://www.espn.com/nhl/playbyplay?gameId=400884397&period=0)

# %%
import pandas 
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
from IPython.display import HTML
HTML(url='http://www.espn.com/nhl/playbyplay?gameId=400884397&period=0')
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml">
# <head><script src="http://cdn.espn.com/sports/optimizely.js"></script><meta charset="iso-8859-1">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <link rel="icon" sizes="any" mask href="http://a.espncdn.com/favicon.ico">
# <meta name="theme-color" content="#CC0000">
# <script type="text/javascript">
#     if(true && navigator && navigator.userAgent.toLowerCase().indexOf("teamstream") >= 0) {
#         window.location = 'http://m.espn.com/mobilecache/general/apps/sc';
#     }
# </script><title>Toronto Maple Leafs vs. Ottawa Senators - Play By Play - October 12, 2016 - ESPN</title>
# <meta name="google-site-verification" content="xuj1ODRluWa0frM-BjIr_aSHoUC7HB5C1MgmYAM_GkA" />
# <meta name="msvalidate.01" content="B1FEB7C682C46C8FCDA3130F3D18AC28" />
# <meta name="googlebot" content="noodp" />
# <meta name="robots" content="index, follow" />
# ...
